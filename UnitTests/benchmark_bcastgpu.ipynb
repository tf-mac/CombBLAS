# %%
import matplotlib.pyplot as plt
import re

# %%
nccllog="""Backend: NCCL, Size: 1 KB, Time: 0.0152405 ms, Bandwidth: 64.0768 MB/s
current benchmark bytes 2048 num of double: 256
bsize 2, count 256, initval 16.1
results are correct and we start benchmark!
Backend: NCCL, Size: 2 KB, Time: 0.0169422 ms, Bandwidth: 115.281 MB/s
current benchmark bytes 4096 num of double: 512
bsize 4, count 512, initval 16.1
results are correct and we start benchmark!
Backend: NCCL, Size: 4 KB, Time: 0.0153502 ms, Bandwidth: 254.476 MB/s
current benchmark bytes 8192 num of double: 1024
bsize 8, count 1024, initval 16.1
results are correct and we start benchmark!
Backend: NCCL, Size: 8 KB, Time: 0.0155816 ms, Bandwidth: 501.393 MB/s
current benchmark bytes 16384 num of double: 2048
bsize 16, count 2048, initval 16.1
results are correct and we start benchmark!
Backend: NCCL, Size: 16 KB, Time: 0.0175163 ms, Bandwidth: 892.024 MB/s
current benchmark bytes 32768 num of double: 4096
bsize 32, count 4096, initval 16.1
results are correct and we start benchmark!
Backend: NCCL, Size: 32 KB, Time: 0.0189101 ms, Bandwidth: 1652.56 MB/s
current benchmark bytes 65536 num of double: 8192
bsize 64, count 8192, initval 16.1
results are correct and we start benchmark!
Backend: NCCL, Size: 64 KB, Time: 0.0197041 ms, Bandwidth: 3171.93 MB/s
current benchmark bytes 131072 num of double: 16384
bsize 128, count 16384, initval 16.1
results are correct and we start benchmark!
Backend: NCCL, Size: 128 KB, Time: 0.0207155 ms, Bandwidth: 6034.11 MB/s
current benchmark bytes 262144 num of double: 32768
bsize 256, count 32768, initval 16.1
results are correct and we start benchmark!
Backend: NCCL, Size: 256 KB, Time: 0.0222435 ms, Bandwidth: 11239.2 MB/s
current benchmark bytes 524288 num of double: 65536
bsize 512, count 65536, initval 16.1
results are correct and we start benchmark!
Backend: NCCL, Size: 512 KB, Time: 0.0246386 ms, Bandwidth: 20293.3 MB/s
current benchmark bytes 1048576 num of double: 131072
bsize 1024, count 131072, initval 16.1
results are correct and we start benchmark!
Backend: NCCL, Size: 1024 KB, Time: 0.0288282 ms, Bandwidth: 34688.3 MB/s
current benchmark bytes 2097152 num of double: 262144
bsize 2048, count 262144, initval 16.1
results are correct and we start benchmark!
Backend: NCCL, Size: 2048 KB, Time: 0.0395033 ms, Bandwidth: 50628.6 MB/s
current benchmark bytes 4194304 num of double: 524288
bsize 4096, count 524288, initval 16.1
results are correct and we start benchmark!
Backend: NCCL, Size: 4096 KB, Time: 0.0530681 ms, Bandwidth: 75374.8 MB/s
current benchmark bytes 8388608 num of double: 1048576
bsize 8192, count 1048576, initval 16.1
results are correct and we start benchmark!
Backend: NCCL, Size: 8192 KB, Time: 0.120373 ms, Bandwidth: 66460.3 MB/s
current benchmark bytes 16777216 num of double: 2097152
bsize 16384, count 2097152, initval 16.1
results are correct and we start benchmark!
Backend: NCCL, Size: 16384 KB, Time: 0.202677 ms, Bandwidth: 78943.4 MB/s
current benchmark bytes 33554432 num of double: 4194304
bsize 32768, count 4194304, initval 16.1
results are correct and we start benchmark!
Backend: NCCL, Size: 32768 KB, Time: 0.253972 ms, Bandwidth: 125998 MB/s
current benchmark bytes 67108864 num of double: 8388608
bsize 65536, count 8388608, initval 16.1
results are correct and we start benchmark!
Backend: NCCL, Size: 65536 KB, Time: 0.411874 ms, Bandwidth: 155387 MB/s"""

# %%
mpi_gpu_log = """Backend: MPI_GPU, Size: 1 KB, Time: 0.442076 ms, Bandwidth: 2.20904 MB/s
current benchmark bytes 2048 num of double: 256
bsize 2, count 256, initval 43.1
results are correct and we start benchmark!
Backend: MPI_GPU, Size: 2 KB, Time: 0.449532 ms, Bandwidth: 4.3448 MB/s
current benchmark bytes 4096 num of double: 512
bsize 4, count 512, initval 43.1
results are correct and we start benchmark!
Backend: MPI_GPU, Size: 4 KB, Time: 0.448173 ms, Bandwidth: 8.71594 MB/s
current benchmark bytes 8192 num of double: 1024
bsize 8, count 1024, initval 43.1
results are correct and we start benchmark!
Backend: MPI_GPU, Size: 8 KB, Time: 0.441658 ms, Bandwidth: 17.689 MB/s
current benchmark bytes 16384 num of double: 2048
bsize 16, count 2048, initval 43.1
results are correct and we start benchmark!
Backend: MPI_GPU, Size: 16 KB, Time: 0.447951 ms, Bandwidth: 34.881 MB/s
current benchmark bytes 32768 num of double: 4096
bsize 32, count 4096, initval 43.1
results are correct and we start benchmark!
Backend: MPI_GPU, Size: 32 KB, Time: 0.449045 ms, Bandwidth: 69.5921 MB/s
current benchmark bytes 65536 num of double: 8192
bsize 64, count 8192, initval 43.1
results are correct and we start benchmark!
Backend: MPI_GPU, Size: 64 KB, Time: 0.448385 ms, Bandwidth: 139.389 MB/s
current benchmark bytes 131072 num of double: 16384
bsize 128, count 16384, initval 43.1
results are correct and we start benchmark!
Backend: MPI_GPU, Size: 128 KB, Time: 0.449352 ms, Bandwidth: 278.178 MB/s
current benchmark bytes 262144 num of double: 32768
bsize 256, count 32768, initval 43.1
results are correct and we start benchmark!
Backend: MPI_GPU, Size: 256 KB, Time: 0.449676 ms, Bandwidth: 555.955 MB/s
current benchmark bytes 524288 num of double: 65536
bsize 512, count 65536, initval 43.1
results are correct and we start benchmark!
Backend: MPI_GPU, Size: 512 KB, Time: 0.447271 ms, Bandwidth: 1117.89 MB/s
current benchmark bytes 1048576 num of double: 131072
bsize 1024, count 131072, initval 43.1
results are correct and we start benchmark!
Backend: MPI_GPU, Size: 1024 KB, Time: 0.452835 ms, Bandwidth: 2208.31 MB/s
current benchmark bytes 2097152 num of double: 262144
bsize 2048, count 262144, initval 43.1
results are correct and we start benchmark!
Backend: MPI_GPU, Size: 2048 KB, Time: 0.453476 ms, Bandwidth: 4410.37 MB/s
current benchmark bytes 4194304 num of double: 524288
bsize 4096, count 524288, initval 43.1
results are correct and we start benchmark!
Backend: MPI_GPU, Size: 4096 KB, Time: 0.458994 ms, Bandwidth: 8714.7 MB/s
current benchmark bytes 8388608 num of double: 1048576
bsize 8192, count 1048576, initval 43.1
results are correct and we start benchmark!
Backend: MPI_GPU, Size: 8192 KB, Time: 0.47317 ms, Bandwidth: 16907.2 MB/s
current benchmark bytes 16777216 num of double: 2097152
bsize 16384, count 2097152, initval 43.1
results are correct and we start benchmark!
Backend: MPI_GPU, Size: 16384 KB, Time: 0.508111 ms, Bandwidth: 31489.2 MB/s
current benchmark bytes 33554432 num of double: 4194304
bsize 32768, count 4194304, initval 43.1
results are correct and we start benchmark!
Backend: MPI_GPU, Size: 32768 KB, Time: 0.578814 ms, Bandwidth: 55285.4 MB/s
current benchmark bytes 67108864 num of double: 8388608
bsize 65536, count 8388608, initval 43.1
results are correct and we start benchmark!
Backend: MPI_GPU, Size: 65536 KB, Time: 0.689705 ms, Bandwidth: 92793.2 MB/s"""

# %%
# parse nccl
nccl_sizes_kb = [int(match[0]) for match in re.findall(r'Size: (\d+) KB, Time: [\d.]+ ms, Bandwidth: ([\d.]+) MB/s', nccllog)]
nccl_bandwidths = [float(match[1]) for match in re.findall(r'Size: (\d+) KB, Time: [\d.]+ ms, Bandwidth: ([\d.]+) MB/s', nccllog)]

# parse mpi cuda aware
mpi_sizes_kb = [int(match[0]) for match in re.findall(r'Size: (\d+) KB, Time: [\d.]+ ms, Bandwidth: ([\d.]+) MB/s', mpi_gpu_log)]
mpi_bandwidths = [float(match[1]) for match in re.findall(r'Size: (\d+) KB, Time: [\d.]+ ms, Bandwidth: ([\d.]+) MB/s', mpi_gpu_log)]


# Convert KB to MB for x-axis
nccl_sizes_mb = [x / 1024 for x in nccl_sizes_kb]
mpi_sizes_mb = [x / 1024 for x in mpi_sizes_kb]


# Plot both NCCL and MPI_GPU
plt.figure(figsize=(6, 6),dpi=150)
plt.plot(nccl_sizes_mb, nccl_bandwidths, marker='o', label='NCCL')
plt.plot(mpi_sizes_mb, mpi_bandwidths, marker='s', label='MPI CUDA-aware')
# plt.title('Bandwidth vs Message Size')
plt.xlabel('Message Size (MB)')
plt.ylabel('Bandwidth (MB/s)')
plt.grid(True)
plt.xscale('log', base=2)
plt.yscale('log')
plt.legend()
plt.tight_layout()
plt.savefig("ncclvsmpi.png",bbox_inches="tight")
plt.show()

# # Plot
# # plt.figure(figsize=(6, 6))
# plt.plot(nccl_sizes_kb, nccl_bandwidths, marker='o')
# plt.title('NCCL Bandwidth vs Message Size')
# plt.xlabel('Message Size (KB)')
# plt.ylabel('Bandwidth (MB/s)')
# plt.grid(True)
# plt.xscale('log', base=2)
# plt.yscale('log')
# plt.tight_layout()
# plt.show()
